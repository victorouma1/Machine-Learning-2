# %% [markdown]
# ## Recurrent Neural Networks (RNN)
#
# Recurrent Neural Networks (RNNs) are a class of neural networks designed to handle **sequential data** where order matters, such as:
# - **Time series data** (stock prices, weather data)
# - **Natural language** (text, speech)
# - **Video frames**
#
# Unlike traditional feedforward networks, RNNs have **loops** that allow information to persist across time steps, enabling them to learn **temporal dependencies**.
#
# - Traditional neural networks treat inputs and outputs as **independent**.
# - RNNs introduce a **hidden state** that carries information from previous time steps, giving the network a **memory**.
#
# At each time step `t`:
# - **Input:** \( x_t \) (current input)
# - **Hidden state:** \( h_t \) (depends on \( h_{t-1} \) and \( x_t \))
# - **Output:** \( y_t \)
#
# The hidden state acts as a **summary of past inputs**.
#
# ### RNN Architecture
#
# 1. `Input Layer`: Takes a sequence of inputs (x₁, x₂, x₃, …).
# 2. `Hidden State (hₜ)`: Stores information about previous inputs. At each time step t, the hidden state is updated using the current input and the previous hidden state:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# 3. Output Layer: Produces an output (yₜ) at each time step:
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
#
# ### Types of RNN
# | Type                           | Description                                           | Example Use Case                   |
# |--------------------------------|-------------------------------------------------------|-------------------------------------|
# | **Many-to-One**                | Sequence input → Single output                        | Sentiment analysis, fraud detection |
# | **One-to-Many**                | Single input → Sequence output                        | Image captioning                    |
# | **Many-to-Many (synchronous)** | Input & output sequences have the **same length**      | Named Entity Recognition (NER)      |
# | **Many-to-Many (asynchronous)**| Input & output sequences have **different lengths**   | Machine translation                  |
#
# ### Training RNNs
#
# ### Backpropagation Through Time (BPTT)
# - RNNs are trained using **Backpropagation Through Time**, where the network is **unrolled** across time steps and gradients are computed for each step.
#
# ### Challenges
# 1. **Vanishing Gradient Problem**
#    - Gradients shrink during backpropagation, making it hard to learn long-term dependencies.
#    - Early information is forgotten
#    - Hard to learn long sequences
# 2. **Exploding Gradient Problem**
#    - Gradients grow uncontrollably, leading to unstable training.
#
# ### Solutions
# - **Gradient Clipping** to control exploding gradients.
# - Use advanced RNN variants such as **LSTM** and **GRU** to handle vanishing gradients.
#
# ## Variants of RNN
#
# ### Long Short-Term Memory (LSTM)
# - Designed to remember **long-term dependencies** using:
#   - **Input gate**: Controls new information entering memory.
#   - **Forget gate**: Decides what to discard.
#   - **Output gate**: Controls the output from memory.
# - Suitable for tasks like **speech recognition** or **language translation**.
#
# ### Gated Recurrent Unit (GRU)
# - A simplified LSTM with:
#   - **Update gate**
#   - **Reset gate**
# - Faster training and fewer parameters compared to LSTM.
#
# ## Applications
# - **Natural Language Processing (NLP):**
#   - Language modeling, text generation, sentiment analysis, machine translation.
# - **Time Series Forecasting:**
#   - Stock price prediction, weather forecasting, energy demand.
# - **Speech & Audio Processing:**
#   - Speech-to-text, music generation.
# - **Video Analysis:**
#   - Action recognition in video sequences.
#
# ## Advantages
# - Captures **temporal dependencies** in sequential data.
# - Handles variable-length inputs and outputs.
# - Effective for tasks where **context** is important.
#
# ## Limitations
# - Difficult to train on long sequences due to **vanishing/exploding gradients**.
# - Computationally expensive compared to feedforward networks.
# - Slower inference for long sequences.

# %% [markdown]
# ### Implementing a Text Generator Using Recurrent Neural Networks (RNNs)
#
# We'll implement an RNN that learns patterns from a text sequence to generate new text character-by-character.

# %% [markdown]
# #### Importing Necessary Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# %% [markdown]
# #### Defining the Input Text and Prepare Character Set
# We define the input text and identify unique characters in the text which we’ll encode for our model.

# %%
text = "This is Zindua School a software training institute"
chars = sorted(list(set(text)))
char_to_index = {char: i for i, char in enumerate(chars)}
index_to_char = {i: char for i, char in enumerate(chars)}

# %% [markdown]
# #### Creating Sequences and Labels
# To train the RNN, we need sequences of fixed length (seq_length) and the character following each sequence as the label.

# %%
seq_length = 3
sequences = []
labels = []

for i in range(len(text) - seq_length):
    seq = text[i:i + seq_length]
    label = text[i + seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

X = np.array(sequences)
y = np.array(labels)

# %% [markdown]
# #### Converting Sequences and Labels to One-Hot Encoding
# For training we convert X and y into one-hot encoded tensors.

# %%
X_one_hot = tf.one_hot(X, len(chars))
y_one_hot = tf.one_hot(y, len(chars))

# %% [markdown]
# #### Building the RNN Model
# We create a simple RNN model with a hidden layer of 50 units and a Dense output layer with softmax activation.

# %%
model = Sequential()
model.add(SimpleRNN(50, input_shape=(seq_length, len(chars)), activation='relu'))
model.add(Dense(len(chars), activation='softmax'))
# Out:
# c:\Users\user\Desktop\data-science-class\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# #### Compiling and Training the Model
# We compile the model using the categorical_crossentropy loss and train it for 100 epochs.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_one_hot, y_one_hot, epochs=100)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.0417 - loss: 3.0067
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.0417 - loss: 2.9829
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.0625 - loss: 2.9620
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1250 - loss: 2.9419
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.1458 - loss: 2.9217
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.1875 - loss: 2.9019
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1875 - loss: 2.8825
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2083 - loss: 2.8632
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.2292 - loss: 2.8446
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2500 - loss: 2.8259
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.2917 - loss: 2.8067
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.2917 - loss: 2.7874
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.3125 - loss: 2.7676
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3125 - loss: 2.7480
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.3542 - loss: 2.7285
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.3542 - loss: 2.7075
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.3958 - loss: 2.6859
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.4167 - loss: 2.6656
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.4167 - loss: 2.6431
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4167 - loss: 2.6181
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.4167 - loss: 2.5943
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3750 - loss: 2.5689
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.3958 - loss: 2.5443
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.3958 - loss: 2.5172
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3958 - loss: 2.4900
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3958 - loss: 2.4620
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.3958 - loss: 2.4330
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4167 - loss: 2.4041
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4167 - loss: 2.3763
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4167 - loss: 2.3431
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.4167 - loss: 2.3125
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.4167 - loss: 2.2834
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.4167 - loss: 2.2547
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4167 - loss: 2.2269
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4167 - loss: 2.1968
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4167 - loss: 2.1691
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.4167 - loss: 2.1406
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.4167 - loss: 2.1132
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.4375 - loss: 2.0841
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.4583 - loss: 2.0579
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.4583 - loss: 2.0314
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5208 - loss: 2.0029
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5417 - loss: 1.9743
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5208 - loss: 1.9444
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5208 - loss: 1.9151
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5417 - loss: 1.8856
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5417 - loss: 1.8560
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5833 - loss: 1.8259
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5833 - loss: 1.7957
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5833 - loss: 1.7675
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5833 - loss: 1.7363
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5833 - loss: 1.7074
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6042 - loss: 1.6769
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6250 - loss: 1.6472
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6250 - loss: 1.6164
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.6250 - loss: 1.5863
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6250 - loss: 1.5549
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.6458 - loss: 1.5242
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.6667 - loss: 1.4945
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step - accuracy: 0.6667 - loss: 1.4635
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.6667 - loss: 1.4321
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6875 - loss: 1.4015
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6875 - loss: 1.3723
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.6875 - loss: 1.3418
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.6875 - loss: 1.3114
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6875 - loss: 1.2814
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6875 - loss: 1.2528
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6875 - loss: 1.2218
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7083 - loss: 1.1919
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7083 - loss: 1.1625
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7083 - loss: 1.1334
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.7083 - loss: 1.1041
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.7083 - loss: 1.0766
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6875 - loss: 1.0488
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6875 - loss: 1.0189
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.7083 - loss: 0.9924
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.7500 - loss: 0.9637
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7708 - loss: 0.9367
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8333 - loss: 0.9102
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8333 - loss: 0.8829
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8542 - loss: 0.8587
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8542 - loss: 0.8346
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8750 - loss: 0.8098
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8750 - loss: 0.7843
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9167 - loss: 0.7615
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9375 - loss: 0.7360
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9583 - loss: 0.7158
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9583 - loss: 0.6932
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9583 - loss: 0.6727
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9583 - loss: 0.6524
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9583 - loss: 0.6316
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9583 - loss: 0.6124
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9583 - loss: 0.5933
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9583 - loss: 0.5742
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9583 - loss: 0.5572
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9583 - loss: 0.5395
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.9583 - loss: 0.5239
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9583 - loss: 0.5077
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9583 - loss: 0.4927
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9583 - loss: 0.4775

# %% [markdown]
# #### Generating New Text Using the Trained Model
# After training we use a starting sequence to generate new text character by character.

# %%
start_seq = "This is Z"
generated_text = start_seq

for i in range(50):
    x = np.array([[char_to_index[char] for char in generated_text[-seq_length:]]])
    x_one_hot = tf.one_hot(x, len(chars))
    prediction = model.predict(x_one_hot)
    next_index = np.argmax(prediction)
    next_char = index_to_char[next_index]
    generated_text += next_char

print("Generated Text:")
print(generated_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Generated Text:
# This is Zindua School a software training ins is is is is i
